# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
cid = "4f9ac9f74ebf4a128987f3e354136b43"
secret = "90299e2c630741f4bbdd0800f3720f34"


client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
import pandas as pd


playlist_link = "https://open.spotify.com/playlist/3hsxJKyaKQ8Qaass78HD0E?si=4020ca05ee4c411e"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
tracks_info = [x["track"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# df = pd.DataFrame(columns = track_columns)
# df.head()
# track_columns
tracks_info[0].items()
# Out:
# dict_items([('album', {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sFIWsNpZYqfjUpaCgueju'}, 'href': 'https://api.spotify.com/v1/artists/6sFIWsNpZYqfjUpaCgueju', 'id': '6sFIWsNpZYqfjUpaCgueju', 'name': 'Carly Rae Jepsen', 'type': 'artist', 'uri': 'spotify:artist:6sFIWsNpZYqfjUpaCgueju'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'GB', 'AD', 'LI', 'MC', 'ID', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'D
# ...

# %%
def get_key_vals(lis):
    keys = []
    vals = []
    for key_val in lis:
        keys.append(key_val[0])
        vals.append(key_val[1])

    res = {}
    for key in keys:
        for value in vals:
            res[key] = value
            vals.remove(value)
            break

    return res

        
def add_playlist(link):
    playlist_link = link
    playlist_URI = playlist_link.split("/")[-1].split("?")[0]
    tracks_info = [x["track"] for x in sp.playlist_tracks(playlist_URI)["items"]]

    for track in sp.playlist_tracks(playlist_URI)["items"]:
        track_uri = track["track"]["uri"]
        print(track_uri)
        song_data = list(sp.audio_features(track_uri)[0].items())
    
    
        dict_vals = get_key_vals(song_data)
        print (dict_vals)

        # for key, val in dict_vals:
    #     df_dictionary = pd.DataFrame([dict_vals])
        
    #     df = pd.concat([df] + df_dictionary, ignore_index=True)

    # return df
    
        
    # for key, val in song_data:

    #     df[]
    #     print (key, val)

    
    
    # print (song_data)
    # song_data = sp.audio_features(track_uri).items()
    # for list(song_data):
    #     print (dancibility)
# df = add_playlist("https://open.spotify.com/playlist/3hsxJKyaKQ8Qaass78HD0E?si=4020ca05ee4c411e")       
# df = add_playlist("https://open.spotify.com/playlist/5lo5HOVfboBH7WudC1BXKO?si=9b7cfc9b0ec94324")
# df.head()

# %%
add_playlist("https://open.spotify.com/playlist/3hsxJKyaKQ8Qaass78HD0E?si=4020ca05ee4c411e")
# Out:
# spotify:track:20I6sIOMTCkB6w7ryavxtO
# {'danceability': 0.783, 'energy': 0.58, 'key': 7, 'loudness': -6.548, 'mode': 1, 'speechiness': 0.0408, 'acousticness': 0.0114, 'instrumentalness': 2.28e-06, 'liveness': 0.108, 'valence': 0.66, 'tempo': 120.021, 'type': 'audio_features', 'id': '20I6sIOMTCkB6w7ryavxtO', 'uri': 'spotify:track:20I6sIOMTCkB6w7ryavxtO', 'track_href': 'https://api.spotify.com/v1/tracks/20I6sIOMTCkB6w7ryavxtO', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20I6sIOMTCkB6w7ryavxtO', 'duration_ms': 193400, 'time_signature': 4}
# spotify:track:27tNWlhdAryQY04Gb2ZhUI
# ...

# %%
len(df)
# Out:
# 100

# %%
df
# Out:
#     danceability  energy key  loudness mode  speechiness  acousticness  \
# 0          0.520   0.849   9    -3.794    0       0.1860       0.00253
# 1          0.750   0.404   9   -10.178    0       0.0682       0.21600
# 2          0.449   0.585   5    -6.761    1       0.0268       0.05090
# 3          0.721   0.613  11    -7.051    0       0.0332       0.00745
# 4          0.583   0.634   2    -7.431    1       0.0325       0.00907
# ..           ...     ...  ..       ...  ...          ...           ...
# 95         0.851   0.806   4    -4.620    1       0.0787       0.11800
# 96         0.647   0.844   0    -3.756    1       0.0457       0.01370
# 97         0.699   0.654  11    -6.264    1       0.0383       0.05400
# 98         0.696   0.686   5    -6.113    0       0.0309       0.26200
# 99         0.803   0.750  11    -4.670    1       0.0551       0.02330
#
#    instrumentalness  liveness  valence    tempo            type  \
# ...
